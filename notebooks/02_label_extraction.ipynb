# %% [markdown]
# This Jupyter notebook is for exploratory testing and prototyping (March milestone in dashboard). It's not a core script but a place to test extractors interactively. (as Markdown cells with code)

# %% [markdown]
# # 02_label_extraction.ipynb
#
# ## Import and Setup
# import sys
# sys.path.append('../src')  # Adjust if needed
# from nlp.labels import LabelHierarchy
# from nlp.utils.aggregate_reports import aggregate_and_label_reports, generate_quality_dashboard
#
# lh = LabelHierarchy()
#
# ## Test Rule-Based
# report = "Bilateral pneumonic changes with no tb. Mild cardiomegaly."
# pathologies = lh.rule_based_extractor(report)
# print("Rule-Based:", pathologies)
# print("Hierarchy:", lh.get_hierarchy(pathologies))
#
# ## Test Full Pipeline on Sample Data
# # Assume small Excel with 'report_text' column
# df = aggregate_and_label_reports('path/to/sample.xlsx')
# print(df.head())
#
# ## Generate Dashboard
# generate_quality_dashboard(df)
